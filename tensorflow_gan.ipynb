# %%
from Gan import GAN

gan = GAN(input_dimension=(28, 28, 1),
          discriminator_conv_filters=[64, 64, 128, 128],
          discriminator_conv_kernel_size=[5,5,5,5],
          discriminator_conv_strides=[2,2,2,1],
          discriminator_batch_norm_momentum=None,
          discriminator_activation='relu',
          discriminator_dropout_rate=0.4,
          discriminator_learning_rate=0.0008,
          generator_initial_dense_layer_size=(7,7,64),
          generator_upsample=[2,2,1,1],
          generator_conv_filters=[128, 64, 64, 1],
          generator_conv_kernel_size=[5, 5, 5, 5],
          generator_conv_strides=[1, 1, 1, 1],
          generator_batch_norm_momentum=0.9,
          generator_activation='relu',
          generator_dropout_rate=None,
          generator_learning_rate=0.0004, z_dim=100)

# %%
gan.discriminator_model()
# Out:
# 2022-05-05 19:07:45.584354: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-05 19:07:45.644092: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-05 19:07:45.644364: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-05 19:07:45.645052: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# ...

# %%
gan.generator_model()

# %%
gan.build_adversarial()

# %%
from Gan import load_mnist_gan
(x_train, y_train), (x_test, y_test) = load_mnist_gan()

# %%
# Wczytanie poprzednio zapisanego modelu
gan.load_model()
# Out:
# Load weights from folder run
# Load epoch number 49 from file

# %%
epochs = 200
batch_size = 64
gan.train(x_train, batch_size=batch_size, epochs=epochs)
# Out:
# Epoka: 0
# 2022-05-05 19:07:56.489420: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8303
# 2022-05-05 19:07:57.740132: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# [D loss: (0.7347992658615112)(R 0.684691309928894, F 0.7849072217941284)]
# [D acc: (0.2890625)(R 0.578125, F 0.0)]
# [G loss: 0.654594898223877]
# [G acc: 1.0]
#
#
# Epoka: 1
# [D loss: (1.0545918941497803)(R 0.5848469734191895, F 1.524336814880371)]
# [D acc: (0.5)(R 1.0, F 0.0)]
# [G loss: 0.6744439601898193]
# [G acc: 1.0]
#
#
# Epoka: 2
# [D loss: (0.6185332834720612)(R 0.5230915546417236, F 0.7139750123023987)]
# [D acc: (0.5)(R 1.0, F 0.0)]
# [G loss: 0.4536140561103821]
# [G acc: 1.0]
#
#
# Epoka: 3
# [D loss: (1.6049341559410095)(R 0.10450971126556396, F 3.105358600616455)]
# [D acc: (0.5)(R 1.0, F 0.0)]
# [G loss: 0.6175398826599121]
# [G acc: 1.0]
#
#
# Epoka: 4
# ...

# %%
gan.plot_loss()

# %%
gan.plot_accuracy()

# %%
gan.plot_model()

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

n_to_show = 20
indices = np.random.choice(range(len(x_test)), n_to_show)
fig = plt.figure(figsize=(30,30))
fig.subplots_adjust(hspace=0.4, wspace=0.4)


for i, idx in enumerate(indices):
    img = x_test[idx]
    ax = fig.add_subplot(5, 5, i+1)
    ax.axis('off')
    ax.imshow(img, cmap='gray')
fig.savefig(os.path.join(os.getcwd(), f"run/datasets/dataset_images.png"))
